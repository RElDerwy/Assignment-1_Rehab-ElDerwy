# %%
x = float(input("x: 35"))
y = float(input("y: 40"))

print(f"▪ Their sum: {x + y}")
print(f"▪ Their difference (x - y): {x - y}")
print(f"▪ Their product: {x * y}")
# Out:
# ▪ Their sum: 75.0
# ▪ Their difference (x - y): -5.0
# ▪ Their product: 1400.0

# %%
x = float(input("x: 35"))
y = float(input("y: 40"))

# x is greater than the y
if x > y:
    print(f"x ({x}) is greater than y ({y})")
if x < y:
    print(f"x ({x}) is less than y ({y})") 
if x == y:
    print(f"x ({x}) is equal to y ({y})")   
    else:
# Out:
# x (35.0) is less than y (40.0)

# %%
# Define variables for my info
name = "Rehab ElDerwy"  
age = 50
height = 164.5  # in centimeters
is_student = None

print(f"Hello, my name is {name}. I am {age} years old and {height} centemeter tall.")
print(f"My student status is: {is_student}")
# Out:
# Hello, my name is Rehab ElDerwy. I am 50 years old and 164.5 centemeter tall.
# My student status is: None

# %%
name = input("Rehab ElDerwy")
age = int(input(50))
height = float(input(164.5))
is_student_input = input("Are you currently a student? (yes/no): ").lower()
is_student = True if is_student_input == 'yes' else False

print(f"Hello, my name is {name}. I am {age} years old and {height} Centemeter tall.")
print(f"My student status is: {is_student}.")
# Out:
# Hello, my name is Rehab ElDerwy. I am 50 years old and 164.5 Centemeter tall.
# My student status is: False.
